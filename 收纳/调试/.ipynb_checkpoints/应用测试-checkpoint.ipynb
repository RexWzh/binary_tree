# %% [markdown]
# ## 测试

# %%
from btree import BTree
from btree import *

# %%
# 旧树：通过一维列表初始化
n = 8
positions = [None for i in range(2**n)]
pos = [1, 
       2,3, 
       4,5, 
       8,9,10,11, 
       16,17,22,23, 
       32,33,34,35,46,47,
       68,69,70,71,
       136,137,138,139,142,143]
value = [0,
        0,10,
        0,0,
        0,20,5,0,
        0,0,7,0,
        10,20,0,0,0,6,
        0,0,5,0,
        10,6,3,10,7,2]
for p,v in zip(pos,value):
    positions[p-1] = v

# 旧树信息
old_tree = BTree.list_to_tree(positions)
old_nodes = {node.position for node in old_tree}
old_leafs = {node.position for node in old_tree.leaves}
print(old_tree)

# %%
# 叶节点转非叶
leaves_seq = [0,0,3,0,3,0,4,0]
nonleaves = leaves_to_nonleaves(leaves_seq)
print(nonleaves)

# 新树：非叶节点转树
new_trees = nonleaves_to_trees(nonleaves)

# %%
min_cost = sum(value) # 最小开销
optimals = [] # 最优解
operates = [] # 最优操作

for new_tree in new_trees:
    # 新树信息
    new_leafs = {node.position for node in new_tree.leaves}
    new_nodes = {node.position for node in new_tree}
    # 获取操作
    com = old_nodes.difference(old_leafs).intersection(new_leafs)
    sep = new_nodes.difference(new_leafs).intersection(old_leafs)
    # 计算开销
    com_leafs = {leaf for leaf in old_leafs if is_child(leaf,com)}
    nodes = sep.union(com_leafs) # 被修改的节点
    cost = sum(positions[i-1] for i in nodes)
    if cost == min_cost and (sep,com) not in operates:
        optimals.append(new_tree)
        operates.append((sep,com))
    elif cost < min_cost:
        min_cost = cost
        optimals= [new_tree]
        operates = [(sep,com)]

# %%
# 打印结果
print("开销",min_cost)
print(old_tree)
for tree,operate in zip(optimals,operates):
    sep,com = operate
    print("拆分叶节点",sep)
    print("合并",com)
    print(tree)

# %% [markdown]
# ## 主函数

# %%
def binary_tree_cost(positions,nonleaves):
    """求二叉树变形的最优解"""
    old_tree = BTree.list_to_tree(positions)
    old_nodes = {node.position for node in old_tree}
    old_leafs = {node.position for node in old_tree.leaves}
    new_trees = nonleaves_to_trees(nonleaves)
    min_cost = sum(positions[i-1] for i in old_leafs) # 最小开销
    optimals = [] # 最优解
    operates = [] # 最优操作
    for new_tree in new_trees:
        # 新树信息
        new_leafs = {node.position for node in new_tree.leaves}
        new_nodes = {node.position for node in new_tree}
        # 获取操作
        com = old_nodes.difference(old_leafs).intersection(new_leafs)
        sep = new_nodes.difference(new_leafs).intersection(old_leafs)
        # 计算开销
        com_leafs = {leaf for leaf in old_leafs if is_child(leaf,com)}
        nodes = sep.union(com_leafs) # 被修改的节点
        cost = sum(positions[i-1] for i in nodes)
        if cost == min_cost and (sep,com) not in operates:
            optimals.append(new_tree)
            operates.append((sep,com))
        elif cost < min_cost:
            min_cost = cost
            optimals= [new_tree]
            operates = [(sep,com)]
    return operates,optimals,min_cost

# %% [markdown]
# ## 运行示例

# %%
from btree import *
# 定义旧树
n = 8
positions = [None for i in range(2**n)]
pos = [1, 
       2,3, 
       4,5, 
       8,9,10,11, 
       16,17,22,23, 
       32,33,34,35,46,47,
       68,69,70,71,
       136,137,138,139,142,143]
values = [0,
        0,10,
        0,0,
        0,20,5,0,
        0,0,7,0,
        10,20,0,0,0,6,
        0,0,5,0,
        10,6,3,10,7,2]
for p,v in zip(pos,values):
    positions[p-1] = v
leaves = [0,0,3,0,3,0,4,0]
nonleaves = leaves_to_nonleaves(leaves)

# %%
operates,optimals,cost = binary_tree_cost(positions,nonleaves)
old_tree = BTree.list_to_tree(positions)
print(old_tree)
for tree,operate in zip(optimals,operates):
    sep,com = operate
    print("拆分叶节点",sep)
    print("合并",com)
    print(tree)

# %% [markdown]
# ## 随机测试

# %%
from math import factorial
binomial = lambda n,k:factorial(n)//factorial(n-k)//factorial(k)

# %%
def tree_num_by_nonleaves(nonleaves):
    """计算遍历数目"""
    if len(nonleaves)==1:return 1
    fac = 1
    for a,b in zip(nonleaves[:-1],nonleaves[1:]):
        fac *= binomial(2*a,b)
    return fac

# %%
from btree import *
import time
# 定义旧树
n = 8
positions = [None for i in range(2**n)]
pos = [1, 
       2,3, 
       4,5, 
       8,9,10,11, 
       16,17,22,23, 
       32,33,34,35,46,47,
       68,69,70,71,
       136,137,138,139,142,143]
values = [0,
        0,10,
        0,0,
        0,20,5,0,
        0,0,7,0,
        10,20,0,0,0,6,
        0,0,5,0,
        10,6,3,10,7,2]
for p,v in zip(pos,values):
    positions[p-1] = v

def test(n):
    nonleaves = random_nonleaves_seq(n)
    print(nonleaves)
    old_tree = BTree.list_to_tree(positions)
    print(old_tree)
    print("总数目",tree_num_by_nonleaves(nonleaves))
    t = time.time()
    operates,optimals,cost = binary_tree_cost(positions,nonleaves)
    print("用时%.3f"%(time.time()-t))
    for tree,operate in zip(optimals,operates):
        sep,com = operate
        print("最优解数目：%d\t 最优解：%d"%(len(optimals),cost))
        print("拆分叶节点",sep)
        print("合并",com)
        print(tree)

# %%
test(n)
# Out:
# [1, 2, 3, 4, 8, 12, 22, 0]
#
#                                              ______________0
#                                             /               \
#                                         ___0__               10
#                                        /      \
#           ____________________________0        0__
#          /                             \      /   \
#      ___0________________               20   5     0__
#     /                    \                        /   \
#   _0               _______0__                    7     0
#  /  \             /          \                        / \
# 10   20        __0__          0__                    0   6
#               /     \        /   \
#             _0       0      5     0
#            /  \     / \          / \
#           10   6   3   10       7   2
#
# 总数目 30139200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-066325e2a912> in <module>
# ----> 1 test(n)
#
# <ipython-input-34-65aa8339c3ba> in test(n)
#      30     print("总数目",tree_num_by_nonleaves(nonleaves))
#      31     t = time.time()
# ---> 32     operates,optimals,cost = binary_tree_cost(positions,nonleaves)
#      33     print("用时%.3f"%(time.time()-t))
#      34     for tree,operate in zip(optimals,operates):
#
# ~/work_space/1 archive/2 jupyter/Github/binary_tree/调试/btree.py in binary_tree_cost(positions, nonleaves)
#     173     old_nodes = {node.position for node in old_tree}
#     174     old_leafs = {node.position for node in old_tree.leaves}
# --> 175     new_trees = nonleaves_to_trees(nonleaves)
#     176     min_cost = sum(positions[i-1] for i in old_leafs) # 最小开销
#     177     optimals = [] # 最优解
#
# ~/work_space/1 archive/2 jupyter/Github/binary_tree/调试/btree.py in nonleaves_to_trees(nonleaves)
#     122         new_trees = [] # 新一层
#     123         for tree in trees: # 对上层遍历
# --> 124             new_trees.extend(tree.new_trees(ak))
#     125         trees = new_trees
#     126     return new_trees
#
# ~/work_space/1 archive/2 jupyter/Github/binary_tree/调试/btree.py in new_trees(self, k)
#      27         num = len(last_layer)
#      28         indexs = choose(list(range(num)),k)
# ---> 29         return [self.new_tree_by_index(index) for index in indexs]
#      30
#      31     def new_tree_by_index(self,index):
#
# ~/work_space/1 archive/2 jupyter/Github/binary_tree/调试/btree.py in <listcomp>(.0)
#      27         num = len(last_layer)
#      28         indexs = choose(list(range(num)),k)
# ---> 29         return [self.new_tree_by_index(index) for index in indexs]
#      30
#      31     def new_tree_by_index(self,index):
#
# ~/work_space/1 archive/2 jupyter/Github/binary_tree/调试/btree.py in new_tree_by_index(self, index)
#      33         输入：最后一层的节点索引"""
#      34         # 复制对象
# ---> 35         tree = deepcopy(self)
#      36         # 获取最后一层
#      37         last_layer = tree.last_layer
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# /usr/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /usr/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# /usr/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /usr/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# /usr/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /usr/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# /usr/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /usr/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# /usr/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /usr/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# /usr/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# /usr/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     142     cls = type(x)
#     143
# --> 144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
#     146         y = copier(x, memo)
#
# KeyboardInterrupt:

# %%
acceptable = 0
intolerable = 0
for i in range(1000000):
    nonleaves = random_nonleaves_seq(n)
    num = tree_num_by_nonleaves(nonleaves)
    if num < 10**7:
        acceptable += 1
    else:
        intolerable += 1
acceptable,intolerable
# Out:
# (900403, 99597)

# %%
nonleaves = [1, 2, 4, 8, 16, 26, 26, 0]
tree_num_by_nonleaves(nonleaves)
# Out:
# 449397407209308259968

# %%
from binarytree import tree,bst,Node

# %%
graph = t.graphviz()
graph.render("test")
# Out:
# 'test.pdf'

# %%
t = bst(height=5, is_perfect=True)
leaves = t.leaves
for a in [26,26]:
    new_leaves = []
    for i in range(a):
        leaves[i].left = Node(0)
        leaves[i].right = Node(0)
        new_leaves.extend([leaves[i].left,leaves[i].right])
    leaves = new_leaves

# %%
[1, 2, 4, 7, 12, 24, 29, 0]
[1, 2, 3, 4, 8, 12, 22, 0]
# Out:
# Node(31)
